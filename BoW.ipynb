# %%
import os
import pandas as pd

# %%
file_path = os.path.join(os.getcwd(), 'Dataset/spam.csv')
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.isna().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'], inplace=True)

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.columns.tolist()
# Out:
# ['v1', 'v2']

# %%
df.groupby('v1').describe()
# Out:
#         v2
#      count unique                                                top freq
# v1
# ham   4825   4516                             Sorry, I'll call later   30
# spam   747    653  Please call our customer service representativ...    4

# %%
df['label_num'] = df.v1.map({'ham':0, 'spam':1})

# %%
df.head()
# Out:
#      v1                                                 v2  label_num
# 0   ham  Go until jurong point, crazy.. Available only ...          0
# 1   ham                      Ok lar... Joking wif u oni...          0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3   ham  U dun say so early hor... U c already then say...          0
# 4   ham  Nah I don't think he goes to usf, he lives aro...          0

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(0, len(df)):
    review = re.sub('[^A-Za-z]', ' ', df['v2'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(i) for i in review if i not in stopwords.words('english')]
    corpus.append(' '.join(review))

# %%
corpus[:5]
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri wkli comp win fa cup final tkt st may text fa receiv entri question std txt rate c appli',
#  'u dun say earli hor u c alreadi say',
#  'nah think goe usf live around though']

# %% [markdown]
# ## Bag of Words (BoW)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500, binary=True, ngram_range=(2,2)) # Max number of frequency 2500 and Makring Binary as True to work as Binary BoW
X = cv.fit_transform(corpus).toarray()

# %%
print(X.shape)
(cv.vocabulary_)
# Out:
# (5572, 2500)
# {'ok lar': np.int64(1485),
#  'free entri': np.int64(622),
#  'entri wkli': np.int64(538),
#  'wkli comp': np.int64(2426),
#  'cup final': np.int64(374),
#  'std txt': np.int64(1967),
#  'txt rate': np.int64(2198),
#  'rate appli': np.int64(1676),
#  'freemsg hey': np.int64(652),
#  'like fun': np.int64(1155),
#  'per request': np.int64(1541),
#  'request mell': np.int64(1732),
#  'mell mell': np.int64(1286),
#  'mell oru': np.int64(1287),
#  'oru minnaminungint': np.int64(1518),
#  'minnaminungint nurungu': np.int64(1315),
#  'nurungu vettam': np.int64(1464),
#  'vettam set': np.int64(2288),
#  'set callertun': np.int64(1850),
#  'callertun caller': np.int64(204),
#  'caller press': np.int64(202),
#  'press copi': np.int64(1643),
#  'copi friend': np.int64(339),
#  'friend callertun': np.int64(656),
#  'winner valu': np.int64(2414),
#  'valu network': np.int64(2286),
#  'network custom': np.int64(1417),
#  'custom select': np.int64(388),
#  'select receivea': np.int64(1808),
#  'reward claim': np.int64(1745),
#  'claim call': np.int64(258),
#  'call claim': np.int64(157),
#  'claim code': np.int64(259),
#  'valid hour': np.int64(2283),
#  'entitl updat': np.int64(535),
#  'updat latest': np.int64(2223),
#  'latest colour': np.int64(1125),
#  'free call': np.int64(617),
#  'call mobil': np.int64(179),
#  'mobil updat': np.int64(1343),
#  'updat co': np.int64(2222),
#  'co free': np.int64(273),
#  'want talk': np.int64(2344),
#  'chanc win': np.int64(239),
#  'win cash': np.int64(2401),
#  'csh send': np.int64(370),
#  'send cost': np.int64(1817),
#  'day day': np.int64(427),
#  'repli hl': np.int64(1720),
#  'hl info': np.int64(951),
#  'week free': np.int64(2365),
#  'txt word': np.int64(2204),
#  'dont miss': np.int64(492),
#  'txt ur': np.int64(2203),
#  'go tri': np.int64(779),
#  'ha ha': np.int64(888),
#  'finish lunch': np.int64(586),
#  'go str': np.int64(771),
#  'ard smth': np.int64(55),
#  'finish ur': np.int64(587),
#  'get worri': np.int64(724),
#  'let know': np.int64(1144),
#  'feel like': np.int64(569),
#  'yeah got': np.int64(2486),
#  'tell anyth': np.int64(2037),
#  'mobil charg': np.int64(1333),
#  'charg month': np.int64(242),
#  'repli ye': np.int64(1729),
#  'yup ok': np.int64(2497),
#  'ok go': np.int64(1482),
#  'go home': np.int64(752),
#  'anyth lor': np.int64(47),
#  'great weekend': np.int64(850),
#  'want need': np.int64(2336),
#  'need crave': np.int64(1405),
#  'tri call': np.int64(2172),
#  'call repli': np.int64(191),
#  'repli sm': np.int64(1725),
#  'free nokia': np.int64(630),
#  'nokia mobil': np.int64(1447),
#  'mobil free': np.int64(1338),
#  'free camcord': np.int64(618),
#  'pleas call': np.int64(1605),
#  'call deliveri': np.int64(163),
#  'deliveri tomorrow': np.int64(461),
#  'hope like': np.int64(981),
#  'lt gt': np.int64(1227),
#  'gt inch': np.int64(858),
#  'call messag': np.int64(176),
#  'messag miss': np.int64(1293),
#  'miss call': np.int64(1323),
#  'anyth go': np.int64(46),
#  'want go': np.int64(2332),
#  'go hospit': np.int64(753),
#  'kept tell': np.int64(1056),
#  'first time': np.int64(591),
#  'like lt': np.int64(1160),
#  'earli tomorrow': np.int64(516),
#  'tomorrow morn': np.int64(2156),
#  'sm ac': np.int64(1883),
#  'repli end': np.int64(1719),
#  'lt url': np.int64(1229),
#  'url gt': np.int64(2273),
#  'congrat year': np.int64(321),
#  'year special': np.int64(2493),
#  'special cinema': np.int64(1946),
#  'cinema pass': np.int64(256),
#  'pass call': np.int64(1527),
#  'call suprman': np.int64(194),
#  'suprman matrix': np.int64(2010),
#  'matrix starwar': np.int64(1269),
#  'starwar etc': np.int64(1964),
#  'etc free': np.int64(539),
#  'free bx': np.int64(616),
#  'bx ip': np.int64(149),
#  'ip pm': np.int64(1026),
#  'pm dont': np.int64(1615),
#  'sorri call': np.int64(1927),
#  'call later': np.int64(175),
#  'later meet': np.int64(1122),
#  'way home': np.int64(2358),
#  'home even': np.int64(966),
#  'ok come': np.int64(1481),
#  'hair dresser': np.int64(891),
#  'cut short': np.int64(392),
#  'valu custom': np.int64(2285),
#  'custom pleas': np.int64(386),
#  'pleas advis': np.int64(1603),
#  'advis follow': np.int64(12),
#  'follow recent': np.int64(597),
#  'recent review': np.int64(1706),
#  'review mob': np.int64(1743),
#  'mob award': np.int64(1328),
#  'award bonu': np.int64(77),
#  'bonu prize': np.int64(124),
#  'prize call': np.int64(1651),
#  'send ur': np.int64(1836),
#  'urgent ur': np.int64(2271),
#  'ur award': np.int64(2226),
#  'month end': np.int64(1349),
#  'hi babe': np.int64(942),
#  'im home': np.int64(1005),
#  'call free': np.int64(164),
#  'that cool': np.int64(2073),
#  'gentleman treat': np.int64(685),
#  'treat digniti': np.int64(2171),
#  'digniti respect': np.int64(474),
#  'hi hi': np.int64(946),
#  'place man': np.int64(1588),
#  'came back': np.int64(206),
#  'still tonight': np.int64(1976),
#  'wen ur': np.int64(2381),
#  'smile pain': np.int64(1899),
#  'like rain': np.int64(1163),
#  'smile becoz': np.int64(1894),
#  'someon still': np.int64(1917),
#  'still love': np.int64(1974),
#  'love see': np.int64(1216),
#  'see smile': np.int64(1799),
#  'call custom': np.int64(161),
#  'custom servic': np.int64(389),
#  'servic repres': np.int64(1848),
#  'repres pm': np.int64(1731),
#  'pm guarante': np.int64(1616),
#  'guarante cash': np.int64(877),
#  'cash prize': np.int64(232),
#  'finish work': np.int64(588),
#  'free rington': np.int64(635),
#  'wat abt': np.int64(2348),
#  'need get': np.int64(1407),
#  'get home': np.int64(700),
#  'love lot': np.int64(1212),
#  'get cash': np.int64(692),
#  'alway one': np.int64(23),
#  'dont worri': np.int64(498),
#  'go dinner': np.int64(747),
#  'dun like': np.int64(510),
#  'tri contact': np.int64(2173),
#  'contact last': np.int64(328),
#  'last weekend': np.int64(1119),
#  'weekend draw': np.int64(2372),
#  'draw show': np.int64(502),
#  'show prize': np.int64(1860),
#  'prize guarante': np.int64(1655),
#  'guarante call': np.int64(876),
#  'code valid': np.int64(280),
#  'valid hr': np.int64(2284),
#  'hr ppm': np.int64(992),
#  'enter cabin': np.int64(531),
#  'cabin pa': np.int64(150),
#  'pa said': np.int64(1520),
#  'said happi': np.int64(1767),
#  'happi day': np.int64(904),
#  'day boss': np.int64(420),
#  'boss felt': np.int64(128),
#  'felt special': np.int64(572),
#  'special askd': np.int64(1944),
#  'askd lunch': np.int64(70),
#  'lunch lunch': np.int64(1233),
#  'lunch invit': np.int64(1232),
#  'invit apart': np.int64(1022),
#  'apart went': np.int64(52),
#  'winner special': np.int64(2413),
#  'special select': np.int64(1950),
#  'select receiv': np.int64(1807),
#  'holiday flight': np.int64(961),
#  'flight inc': np.int64(594),
#  'inc speak': np.int64(1013),
#  'speak live': np.int64(1942),
#  'live oper': np.int64(1174),
#  'oper claim': np.int64(1506),
#  'buy food': np.int64(148),
#  'privat account': np.int64(1650),
#  'account statement': np.int64(8),
#  'statement show': np.int64(1965),
#  'show unredeem': np.int64(1862),
#  'unredeem bonu': np.int64(2218),
#  'bonu point': np.int64(123),
#  'point claim': np.int64(1625),
#  'call identifi': np.int64(171),
#  'identifi code': np.int64(999),
#  'code expir': np.int64(278),
#  'urgent mobil': np.int64(2267),
#  'mobil award': np.int64(1332),
#  'bonu caller': np.int64(122),
#  'caller prize': np.int64(203),
#  'prize final': np.int64(1654),
#  'contact call': np.int64(324),
#  'call landlin': np.int64(174),
#  'today voda': np.int64(2149),
#  'voda number': np.int64(2296),
#  'number end': np.int64(1460),
#  'end select': np.int64(528),
#  'receiv award': np.int64(1703),
#  'award match': np.int64(82),
#  'match pleas': np.int64(1266),
#  'call quot': np.int64(189),
#  'quot claim': np.int64(1672),
#  'code standard': np.int64(279),
#  'standard rate': np.int64(1960),
#  'rate app': np.int64(1675),
#  'wat time': np.int64(2350),
#  'time finish': np.int64(2117),
#  'sent text': np.int64(1840),
#  'hope well': np.int64(985),
#  'long time': np.int64(1184),
#  'time give': np.int64(2119),
#  'give call': np.int64(733),
#  'dear call': np.int64(449),
#  'answer question': np.int64(42),
#  'sunshin quiz': np.int64(2008),
#  'quiz wkli': np.int64(1671),
#  'wkli win': np.int64(2428),
#  'win top': np.int64(2410),
#  'top soni': np.int64(2170),
#  'soni dvd': np.int64(1925),
#  'dvd player': np.int64(515),
#  'player know': np.int64(1601),
#  'know countri': np.int64(1067),
#  'txt ansr': np.int64(2186),
#  'ansr sp': np.int64(40),
#  'sp tyron': np.int64(1941),
#  'want get': np.int64(2331),
#  'get laid': np.int64(702),
#  'tonight want': np.int64(2167),
#  'want real': np.int64(2339),
#  'real dog': np.int64(1689),
#  'dog locat': np.int64(483),
#  'locat sent': np.int64(1176),
#  'sent direct': np.int64(1838),
#  'direct ur': np.int64(476),
#  'ur mob': np.int64(2247),
#  'join uk': np.int64(1035),
#  'uk largest': np.int64(2210),
#  'largest dog': np.int64(1112),
#  'dog network': np.int64(484),
#  'check room': np.int64(250),
#  'room befor': np.int64(1758),
#  'befor activ': np.int64(106),
#  'go get': np.int64(748),
#  'text way': np.int64(2061),
#  'sir wait': np.int64(1871),
#  'gud ni': np.int64(883),
#  'ye see': np.int64(2484),
#  'see ya': np.int64(1803),
#  'netcollex ltd': np.int64(1416),
#  'per msg': np.int64(1539),
#  'msg repli': np.int64(1371),
#  'repli stop': np.int64(1726),
#  'stop end': np.int64(1983),
#  'got job': np.int64(821),
#  'birla soft': np.int64(112),
#  'yup thk': np.int64(2498),
#  'need go': np.int64(1408),
#  'time done': np.int64(2115),
#  'leav hous': np.int64(1137),
#  'hello love': np.int64(932),
#  'happi good': np.int64(905),
#  'good boy': np.int64(801),
#  'think miss': np.int64(2086),
#  'new year': np.int64(1431),
#  'receiv cash': np.int64(1704),
#  'cash holiday': np.int64(231),
#  'miss alreadi': np.int64(1321),
#  'new job': np.int64(1422),
#  'make happi': np.int64(1247),
#  'invit friend': np.int64(1023),
#  'friend repli': np.int64(660),
#  'see www': np.int64(1802),
#  'www sm': np.int64(2465),
#  'stop send': np.int64(1988),
#  'send stop': np.int64(1833),
#  'stop frnd': np.int64(1985),
#  'ur mobil': np.int64(2248),
#  'urgent tri': np.int64(2270),
#  'form clark': np.int64(610),
#  'ya go': np.int64(2476),
#  'time come': np.int64(2114),
#  'come later': np.int64(302),
#  'finish bath': np.int64(585),
#  'know got': np.int64(1070),
#  'got money': np.int64(828),
#  'still go': np.int64(1970),
#  'friend stay': np.int64(661),
#  'back til': np.int64(93),
#  'til lt': np.int64(2104),
#  'gt worth': np.int64(872),
#  'hi spoke': np.int64(949),
#  'spoke maneesha': np.int64(1954),
#  'maneesha like': np.int64(1256),
#  'like know': np.int64(1159),
#  'know satisfi': np.int64(1088),
#  'satisfi experi': np.int64(1774),
#  'experi repli': np.int64(553),
#  'repli toll': np.int64(1727),
#  'toll free': np.int64(2154),
#  'free ye': np.int64(650),
#  'end month': np.int64(527),
#  'get back': np.int64(690),
#  'boytoy miss': np.int64(137),
#  'haha awesom': np.int64(889),
#  'repres freephon': np.int64(1730),
#  'freephon pm': np.int64(653),
#  'time get': np.int64(2118),
#  'reach home': np.int64(1683),
#  'home go': np.int64(968),
#  'go bath': np.int64(742),
#  'co uk': np.int64(277),
#  'keep touch': np.int64(1051),
#  'great week': np.int64(849),
#  'complet cours': np.int64(315),
#  'school year': np.int64(1786),
#  'gr day': np.int64(839),
#  'gud mrng': np.int64(882),
#  'mrng dear': np.int64(1362),
#  'dear hav': np.int64(451),
#  'hav nice': np.int64(911),
#  'nice day': np.int64(1436),
#  'got person': np.int64(830),
#  'person stori': np.int64(1548),
#  'hey tmr': np.int64(940),
#  'hi kate': np.int64(948),
#  'see tomorrow': np.int64(1801),
#  'txt back': np.int64(2187),
#  'sent lt': np.int64(1839),
#  'gt buck': np.int64(852),
#  'love kate': np.int64(1209),
#  'lt decim': np.int64(1226),
#  'decim gt': np.int64(457),
#  'gt keralacircl': np.int64(861),
#  'keralacircl prepaid': np.int64(1058),
#  'rs lt': np.int64(1762),
#  'like dat': np.int64(1154),
#  'give us': np.int64(736),
#  'get readi': np.int64(711),
#  'hope great': np.int64(980),
#  'head toward': np.int64(914),
#  'got select': np.int64(833),
#  'select mean': np.int64(1806),
#  'exam march': np.int64(552),
#  'yeah think': np.int64(2490),
#  'think use': np.int64(2091),
#  'know sure': np.int64(1094),
#  'ok prob': np.int64(1489),
#  'take ur': np.int64(2029),
#  'ur time': np.int64(2258),
#  'new mobil': np.int64(1424),
#  'mobil must': np.int64(1340),
#  'must go': np.int64(1389),
#  'go txt': np.int64(780),
#  'txt nokia': np.int64(2195),
#  'nokia collect': np.int64(1442),
#  'collect today': np.int64(287),
#  'today www': np.int64(2151),
#  'www tc': np.int64(2466),
#  'tc biz': np.int64(2033),
#  'biz optout': np.int64(116),
#  'optout gbp': np.int64(1511),
#  'gbp mtmsg': np.int64(680),
#  'would realli': np.int64(2453),
#  'realli appreci': np.int64(1694),
#  'follow ur': np.int64(598),
#  'happi morn': np.int64(906),
#  'good morn': np.int64(810),
#  'work place': np.int64(2441),
#  'text meet': np.int64(2057),
#  'name age': np.int64(1391),
#  'msg recd': np.int64(1370),
#  'bu stop': np.int64(146),
#  'new theori': np.int64(1427),
#  'theori argument': np.int64(2076),
#  'argument win': np.int64(57),
#  'win situat': np.int64(2407),
#  'situat lose': np.int64(1873),
#  'lose person': np.int64(1197),
#  'person dont': np.int64(1544),
#  'dont argu': np.int64(485),
#  'argu ur': np.int64(56),
#  'ur friend': np.int64(2233),
#  'friend kick': np.int64(658),
#  'kick amp': np.int64(1060),
#  'amp say': np.int64(31),
#  'say alway': np.int64(1778),
#  'alway correct': np.int64(22),
#  'secret admir': np.int64(1790),
#  'admir look': np.int64(11),
#  'look make': np.int64(1187),
#  'make contact': np.int64(1243),
#  'contact find': np.int64(327),
#  'find reveal': np.int64(580),
#  'reveal think': np.int64(1741),
#  'think ur': np.int64(2090),
#  'ur special': np.int64(2256),
#  'special call': np.int64(1945),
#  'told dat': np.int64(2152),
#  'ask call': np.int64(64),
#  'oh ok': np.int64(1478),
#  'good night': np.int64(811),
#  'congratul ur': np.int64(323),
#  'award cd': np.int64(79),
#  'cd voucher': np.int64(237),
#  'voucher gift': np.int64(2305),
#  'gift guarante': np.int64(726),
#  'guarante free': np.int64(878),
#  'wkli draw': np.int64(2427),
#  'draw txt': np.int64(504),
#  'txt music': np.int64(2194),
#  'music tnc': np.int64(1388),
#  'tnc www': np.int64(2134),
#  'www ldew': np.int64(2462),
#  'ldew com': np.int64(1132),
#  'com win': np.int64(294),
#  'win ppmx': np.int64(2406),
#  'ppmx age': np.int64(1641),
#  'ur lovabl': np.int64(2242),
#  'lovabl bcum': np.int64(1201),
#  'bcum angri': np.int64(102),
#  'angri wid': np.int64(37),
#  'wid dnt': np.int64(2393),
#  'dnt take': np.int64(482),
#  'take serious': np.int64(2027),
#  'serious coz': np.int64(1843),
#  'coz angri': np.int64(350),
#  'angri childish': np.int64(36),
#  'childish true': np.int64(251),
#  'true way': np.int64(2178),
#  'way show': np.int64(2360),
#  'show deep': np.int64(1859),
#  'deep affect': np.int64(458),
#  'affect care': np.int64(13),
#  'care luv': np.int64(224),
#  'luv kettoda': np.int64(1235),
#  'kettoda manda': np.int64(1059),
#  'manda nice': np.int64(1255),
#  'day da': np.int64(426),
#  'week get': np.int64(2366),
#  'lemm know': np.int64(1140),
#  'contact repli': np.int64(331),
#  'repli offer': np.int64(1722),
#  'offer video': np.int64(1470),
#  'video handset': np.int64(2291),
#  'handset anytim': np.int64(899),
#  'anytim network': np.int64(50),
#  'network min': np.int64(1418),
#  'min unlimit': np.int64(1312),
#  'unlimit text': np.int64(2217),
#  'text camcord': np.int64(2052),
#  'camcord repli': np.int64(205),
#  'repli call': np.int64(1716),
#  'come today': np.int64(309),
#  'anyway go': np.int64(51),
#  'go shop': np.int64(767),
#  'co si': np.int64(276),
#  'dun disturb': np.int64(508),
#  'disturb liao': np.int64(479),
#  'ring ur': np.int64(1752),
#  'text stop': np.int64(2059),
#  'tri get': np.int64(2175),
#  'get hold': np.int64(699),
#  'stop txt': np.int64(1992),
#  'po box': np.int64(1618),
#  'rington club': np.int64(1753),
#  'messag free': np.int64(1292),
#  'night end': np.int64(1439),
#  'end anoth': np.int64(526),
#  'anoth day': np.int64(38),
#  'day morn': np.int64(440),
#  'morn come': np.int64(1355),
#  'come special': np.int64(308),
#  'special way': np.int64(1952),
#  'way may': np.int64(2359),
#  'may smile': np.int64(1274),
#  'smile like': np.int64(1897),
#  'like sunni': np.int64(1166),
#  'sunni ray': np.int64(2007),
#  'ray leav': np.int64(1679),
#  'leav worri': np.int64(1138),
#  'worri blue': np.int64(2448),
#  'blue blue': np.int64(120),
#  'blue bay': np.int64(119),
#  'hmv bonu': np.int64(953),
#  'bonu special': np.int64(125),
#  'special pound': np.int64(1949),
#  'pound genuin': np.int64(1636),
#  'genuin hmv': np.int64(687),
#  'hmv voucher': np.int64(955),
#  'voucher answer': np.int64(2300),
#  'answer easi': np.int64(41),
#  'easi question': np.int64(519),
#  'question play': np.int64(1669),
#  'play send': np.int64(1599),
#  'send hmv': np.int64(1825),
#  'hmv info': np.int64(954),
#  'info www': np.int64(1017),
#  'www percent': np.int64(2463),
#  'percent real': np.int64(1543),
#  'real com': np.int64(1688),
#  'well take': np.int64(2379),
#  'see bit': np.int64(1793),
#  'got call': np.int64(818),
#  'last night': np.int64(1114),
#  'might come': np.int64(1303),
#  'hi babi': np.int64(943),
#  'babi im': np.int64(90),
#  'fone love': np.int64(599),
#  'lot love': np.int64(1199),
#  'love life': np.int64(1211),
#  'life love': np.int64(1149),
#  'call friend': np.int64(166),
#  'much buzi': np.int64(1378),
#  'mobil custom': np.int64(1336),
#  'custom may': np.int64(384),
#  'may claim': np.int64(1273),
#  'claim free': np.int64(261),
#  'free camera': np.int64(619),
#  'camera phone': np.int64(213),
#  'phone upgrad': np.int64(1560),
#  'sim card': np.int64(1867),
#  'loyalti call': np.int64(1223),
#  'call offer': np.int64(185),
#  'offer end': np.int64(1466),
#  'make cri': np.int64(1244),
#  'cri end': np.int64(356),
#  'keep one': np.int64(1046),
#  'day bslvyl': np.int64(421),
#  'cant pick': np.int64(217),
#  'pick phone': np.int64(1564),
#  'phone right': np.int64(1559),
#  'right pl': np.int64(1748),
#  'pl send': np.int64(1585),
#  'send messag': np.int64(1829),
#  'time week': np.int64(2131),
#  'last time': np.int64(1117),
#  'today accept': np.int64(2137),
#  'accept day': np.int64(5),
#  'day accept': np.int64(416),
#  'accept brother': np.int64(4),
#  'brother sister': np.int64(141),
#  'sister lover': np.int64(1872),
#  'lover dear': np.int64(1222),
#  'dear best': np.int64(448),
#  'best clo': np.int64(108),
#  'clo lvblefrnd': np.int64(269),
#  'lvblefrnd jstfrnd': np.int64(1236),
#  'jstfrnd cutefrnd': np.int64(1038),
#  'cutefrnd lifpartnr': np.int64(395),
#  'lifpartnr belovd': np.int64(1150),
#  'belovd swtheart': np.int64(107),
#  'swtheart bstfrnd': np.int64(2022),
#  'bstfrnd rpli': np.int64(142),
#  'rpli mean': np.int64(1761),
#  'mean enemi': np.int64(1275),
#  'gbp week': np.int64(682),
#  'hope find': np.int64(977),
#  'day great': np.int64(437),
#  'great day': np.int64(843),
#  'decemb mobil': np.int64(456),
#  'mobil mth': np.int64(1339),
#  'mth entitl': np.int64(1375),
#  'colour camera': np.int64(288),
#  'camera mobil': np.int64(212),
#  'merri christma': np.int64(1289),
#  'babe love': np.int64(88),
#  'love ya': np.int64(1221),
#  'go watch': np.int64(782),
#  'would great': np.int64(2450),
#  'get touch': np.int64(717),
#  'good week': np.int64(815),
#  'da today': np.int64(403),
#  'well know': np.int64(2378),
#  'cool text': np.int64(338),
#  'could get': np.int64(345),
#  'call germani': np.int64(168),
#  'per minut': np.int64(1538),
#  'phone number': np.int64(1557),
#  'valentin day': np.int64(2282),
#  'send go': np.int64(1823),
#  'go msg': np.int64(761),
#  'msg rcvd': np.int64(1369),
#  'sleep surf': np.int64(1880),
#  'thanx lot': np.int64(2072),
#  'di yiju': np.int64(468),
#  'ur mail': np.int64(2245),
#  'com txt': np.int64(293),
#  'realli miss': np.int64(1697),
#  'great month': np.int64(844),
#  'today sorri': np.int64(2146),
#  'day ever': np.int64(431),
#  'plz plz': np.int64(1613),
#  'ur fault': np.int64(2231),
#  'tri figur': np.int64(2174),
#  'gt ish': np.int64(860),
#  'insha allah': np.int64(1020),
#  'ur cash': np.int64(2227),
#  'cash balanc': np.int64(229),
#  'balanc current': np.int64(97),
#  'current pound': np.int64(376),
#  'pound maxim': np.int64(1637),
#  'maxim ur': np.int64(1272),
#  'cash send': np.int64(233),
#  'send cash': np.int64(1815),
#  'msg cc': np.int64(1364),
#  'cc hg': np.int64(234),
#  'hg suit': np.int64(941),
#  'suit land': np.int64(2002),
#  'land row': np.int64(1106),
#  'row hl': np.int64(1759),
#  'work even': np.int64(2439),
#  'everi day': np.int64(545),
#  'keep post': np.int64(1047),
#  'look forward': np.int64(1185),
#  'good afternoon': np.int64(800),
#  'think love': np.int64(2085),
#  'take care': np.int64(2023),
#  'latest motorola': np.int64(1126),
#  'motorola sonyericsson': np.int64(1360),
#  'sonyericsson nokia': np.int64(1926),
#  'nokia free': np.int64(1444),
#  'free bluetooth': np.int64(615),
#  'doubl min': np.int64(499),
#  'min txt': np.int64(1311),
#  'txt orang': np.int64(2196),
#  'call mobileupd': np.int64(181),
#  'mobileupd call': np.int64(1347),
#  'call optout': np.int64(186),
#  'messag repli': np.int64(1296),
#  'hello boytoy': np.int64(929),
#  'geeee miss': np.int64(684),
#  'next lt': np.int64(1434),
#  'gt min': np.int64(865),
#  'thank rington': np.int64(2071),
#  'rington order': np.int64(1757),
#  'order refer': np.int64(1516),
#  'per week': np.int64(1542),
#  'say happen': np.int64(1780),
#  'someth go': np.int64(1921),
#  'dont mistak': np.int64(493),
#  'yeah sure': np.int64(2489),
#  'coupl minut': np.int64(348),
#  'month free': np.int64(1350),
#  'nokia motorola': np.int64(1448),
#  'phone call': np.int64(1551),
#  'custom place': np.int64(385),
#  'time dont': np.int64(2116),
#  'dont like': np.int64(490),
#  'mth half': np.int64(1376),
#  'half price': np.int64(894),
#  'price orang': np.int64(1648),
#  'orang line': np.int64(1513),
#  'line rental': np.int64(1168),
#  'rental latest': np.int64(1714),
#  'latest camera': np.int64(1124),
#  'phone free': np.int64(1553),
#  'free phone': np.int64(632),
#  'phone mth': np.int64(1556),
#  'mth call': np.int64(1374),
#  'call mobilesdirect': np.int64(180),
#  'mobilesdirect free': np.int64(1346),
#  'free updat': np.int64(647),
#  'updat stoptxt': np.int64(2224),
#  'time go': np.int64(2120),
#  'call back': np.int64(153),
#  'send text': np.int64(1835),
#  'make feel': np.int64(1246),
#  'good even': np.int64(804),
#  'hope fine': np.int64(978),
#  'wanna get': np.int64(2327),
#  'text get': np.int64(2056),
#  'st free': np.int64(1956),
#  'free tone': np.int64(645),
#  'txt stop': np.int64(2200),
#  'hope day': np.int64(974),
#  'time place': np.int64(2126),
#  'messag text': np.int64(1300),
#  'miss number': np.int64(1327),
#  'date miss': np.int64(410),
#  'sent via': np.int64(1842),
#  'via fullonsm': np.int64(2289),
#  'fullonsm com': np.int64(671),
#  'go yan': np.int64(785),
#  'yan jiu': np.int64(2477),
#  'den go': np.int64(463),
#  'date servic': np.int64(412),
#  'box sk': np.int64(133),
#  'dont want': np.int64(497),
#  'entri weekli': np.int64(537),
#  'text word': np.int64(2062),
#  'ur lover': np.int64(2244),
#  'pobox wq': np.int64(1621),
#  'last week': np.int64(1118),
#  'live call': np.int64(1171),
#  'someon contact': np.int64(1910),
#  'contact date': np.int64(326),
#  'servic enter': np.int64(1846),
#  'enter phone': np.int64(532),
#  'fanci find': np.int64(557),
#  'find call': np.int64(577),
#  'landlin pobox': np.int64(1110),
#  'mobil number': np.int64(1341),
#  'number award': np.int64(1459),
#  'award prize': np.int64(84),
#  'call land': np.int64(173),
#  'land line': np.int64(1105),
#  'line claim': np.int64(1167),
#  'claim valid': np.int64(265),
#  'ok ok': np.int64(1488),
#  'aathi dear': np.int64(0),
#  'co got': np.int64(275),
#  'got car': np.int64(819),
#  'wnt buy': np.int64(2429),
#  'buy bmw': np.int64(147),
#  'bmw car': np.int64(121),
#  'car urgent': np.int64(220),
#  'urgent vri': np.int64(2272),
#  'vri urgent': np.int64(2309),
#  'urgent hv': np.int64(2265),
#  'hv shortag': np.int64(995),
#  'shortag lt': np.int64(1858),
#  'gt lac': np.int64(862),
#  'lac sourc': np.int64(1103),
#  'sourc arng': np.int64(1939),
#  'arng di': np.int64(58),
#  'di amt': np.int64(465),
#  'amt lt': np.int64(35),
#  'lac that': np.int64(1104),
#  'that prob': np.int64(2074),
#  'watch tv': np.int64(2355),
#  'tv lor': np.int64(2183),
#  'video camera': np.int64(2290),
#  'call call': np.int64(156),
#  'call cost': np.int64(158),
#  'cost ppm': np.int64(343),
#  'call min': np.int64(177),
#  'ldn wc': np.int64(1133),
#  'wc xx': np.int64(2362),
#  'gt th': np.int64(870),
#  'messag sent': np.int64(1298),
#  'gt dollar': np.int64(854),
#  'pay lt': np.int64(1530),
#  'gt lt': np.int64(864),
#  'hi hope': np.int64(947),
#  'get txt': np.int64(718),
#  'cricket sachin': np.int64(357),
#  'come get': np.int64(300),
#  'well done': np.int64(2376),
#  'hope good': np.int64(979),
#  'good day': np.int64(803),
#  'ok tell': np.int64(1494),
#  'loan purpos': np.int64(1175),
#  'purpos homeown': np.int64(1664),
#  'homeown tenant': np.int64(972),
#  'tenant welcom': np.int64(2046),
#  'welcom previous': np.int64(2375),
#  'previous refus': np.int64(1645),
#  'refus still': np.int64(1709),
#  'still help': np.int64(1972),
#  'help call': np.int64(934),
#  'free text': np.int64(643),
#  'text back': np.int64(2050),
#  'back help': np.int64(91),
#  'day give': np.int64(435),
#  'thank god': np.int64(2067),
#  'make love': np.int64(1248),
#  'gt time': np.int64(871),
#  'time per': np.int64(2125),
#  'per night': np.int64(1540),
#  'dave final': np.int64(414),
#  'tenerif holiday': np.int64(2047),
#  'holiday cash': np.int64(960),
#  'cash award': np.int64(228),
#  'award call': np.int64(78),
#  'box cw': np.int64(130),
#  'cw wx': np.int64(396),
#  'wx ppm': np.int64(2470),
#  'account lt': np.int64(7),
#  'send account': np.int64(1812),
#  'account detail': np.int64(6),
#  'nyt ec': np.int64(1465),
#  'love aathi': np.int64(1203),
#  'aathi love': np.int64(1),
#  'cant wait': np.int64(218),
#  'real thing': np.int64(1691),
#  'free messag': np.int64(625),
#  'messag activ': np.int64(1291),
#  'text messag': np.int64(2058),
#  'free term': np.int64(642),
#  'term condit': np.int64(2048),
#  'visit www': np.int64(2295),
#  'dear reach': np.int64(452),
#  'sorri man': np.int64(1933),
#  'sorri meet': np.int64(1934),
#  'meet call': np.int64(1277),
#  'think go': np.int64(2081),
#  'fight world': np.int64(573),
#  'world easi': np.int64(2445),
#  'easi either': np.int64(518),
#  'either win': np.int64(524),
#  'win lose': np.int64(2404),
#  'lose bt': np.int64(1195),
#  'bt fightng': np.int64(144),
#  'fightng close': np.int64(574),
#  'close dificult': np.int64(270),
#  'dificult lose': np.int64(472),
#  'lose lose': np.int64(1196),
#  'lose win': np.int64(1198),
#  'win still': np.int64(2408),
#  'still lose': np.int64(1973),
#  'prize claim': np.int64(1652),
#  'call cs': np.int64(159),
#  'cs stop': np.int64(366),
#  'stop sm': np.int64(1989),
#  'sm ppm': np.int64(1888),
#  'pay rent': np.int64(1531),
#  'need help': np.int64(1409),
#  'opinion jada': np.int64(1508),
#  'jada kusruthi': np.int64(1029),
#  'kusruthi lovabl': np.int64(1102),
#  'lovabl silent': np.int64(1202),
#  'silent spl': np.int64(1866),
#  'spl charact': np.int64(1953),
#  'charact matur': np.int64(240),
#  'matur stylish': np.int64(1270),
#  'stylish simpl': np.int64(1999),
#  'simpl pl': np.int64(1868),
#  'pl repli': np.int64(1584),
#  'prabha soryda': np.int64(1642),
#  'soryda reali': np.int64(1936),
#  'reali frm': np.int64(1693),
#  'frm heart': np.int64(667),
#  'heart sori': np.int64(927),
#  'lol ok': np.int64(1181),
#  'guarante latest': np.int64(879),
#  'latest nokia': np.int64(1128),
#  'nokia phone': np.int64(1449),
#  'phone gb': np.int64(1554),
#  'gb ipod': np.int64(679),
#  'ipod mp': np.int64(1027),
#  'mp player': np.int64(1361),
#  'player prize': np.int64(1602),
#  'prize txt': np.int64(1657),
#  'word collect': np.int64(2433),
#  'collect ibhltd': np.int64(285),
#  'ibhltd ldnw': np.int64(997),
#  'ldnw mtmsgrcvd': np.int64(1136),
#  'tone repli': np.int64(2163),
#  'tone txt': np.int64(2165),
#  'http www': np.int64(993),
#  'sat night': np.int64(1773),
#  'want ask': np.int64(2329),
#  'free need': np.int64(628),
#  'need know': np.int64(1410),
#  'shall come': np.int64(1853),
#  'gonna go': np.int64(799),
#  'prize nd': np.int64(1656),
#  'nd attempt': np.int64(1398),
#  'attempt contact': np.int64(73),
#  'call box': np.int64(155),
#  'box qu': np.int64(132),
#  'merri ma': np.int64(1290),
#  'claim ur': np.int64(264),
#  'ur worth': np.int64(2262),
#  'worth discount': np.int64(2449),
#  'discount voucher': np.int64(477),
#  'voucher text': np.int64(2307),
#  'text ye': np.int64(2063),
#  'ye savamob': np.int64(2483),
#  'savamob member': np.int64(1775),
#  'member offer': np.int64(1288),
#  'offer mobil': np.int64(1467),
#  'mobil cs': np.int64(1335),
#  'cs sub': np.int64(367),
#  'next hr': np.int64(1433),
#  'show un': np.int64(1861),
#  'un redeem': np.int64(2214),
#  'redeem point': np.int64(1707),
#  'point call': np.int64(1624),
#  'today sunday': np.int64(2147),
#  'sunday sunday': np.int64(2006),
#  'sunday holiday': np.int64(2005),
#  'holiday work': np.int64(963),
#  'know miss': np.int64(1079),
#  'pl give': np.int64(1580),
#  'afternoon love': np.int64(15),
#  'love goe': np.int64(1207),
#  'goe day': np.int64(794),
#  'passion kiss': np.int64(1528),
#  'kiss across': np.int64(1064),
#  'across sea': np.int64(9),
#  'probabl gonna': np.int64(1659),
#  'see later': np.int64(1796),
#  'later tonight': np.int64(1123),
#  'ummmmmaah mani': np.int64(2213),
#  'mani mani': np.int64(1258),
#  'mani happi': np.int64(1257),
#  'happi return': np.int64(908),
#  'return day': np.int64(1736),
#  'day dear': np.int64(428),
#  'dear sweet': np.int64(453),
#  'sweet heart': np.int64(2019),
#  'heart happi': np.int64(924),
#  'happi birthday': np.int64(902),
#  'birthday dear': np.int64(113),
#  'without lose': np.int64(2423),
#  'go colleg': np.int64(746),
#  'know need': np.int64(1081),
#  'took long': np.int64(2168),
#  'cut hair': np.int64(391),
#  'sure get': np.int64(2011),
#  'everi night': np.int64(546),
#  'cup milk': np.int64(375),
#  'still need': np.int64(1975),
#  'love much': np.int64(1213),
#  'bare stand': np.int64(98),
#  'fuck babe': np.int64(669),
#  'babe miss': np.int64(89),
#  'ill call': np.int64(1000),
#  'go gym': np.int64(751),
#  'love smile': np.int64(1217),
#  'hope ok': np.int64(983),
#  'ok good': np.int64(1483),
#  'day babe': np.int64(419),
#  'miss much': np.int64(1326),
#  'yar lor': np.int64(2478),
#  'wait call': np.int64(2310),
#  'call us': np.int64(200),
#  'us back': np.int64(2274),
#  'need chang': np.int64(1402),
#  'new video': np.int64(1429),
#  'video phone': np.int64(2292),
#  'one day': np.int64(1499),
#  'dun thk': np.int64(511),
#  'thk quit': np.int64(2094),
#  'go jazz': np.int64(755),
#  'go meet': np.int64(760),
#  'ur chanc': np.int64(2228),
#  'shop spree': np.int64(1856),
#  'www txt': np.int64(2468),
#  'custcar wk': np.int64(380),
#  'cs appli': np.int64(361),
#  'import custom': np.int64(1011),
#  'servic announc': np.int64(1844),
#  'call freephon': np.int64(165),
#  'sleep well': np.int64(1881),
#  'go buy': np.int64(745),
#  'send home': np.int64(1826),
#  'home first': np.int64(967),
#  'ok lor': np.int64(1487),
#  'meet lunch': np.int64(1283),
#  'wait see': np.int64(2314),
#  'see get': np.int64(1795),
#  'neva mind': np.int64(1420),
#  'want come': np.int64(2330),
#  'come find': np.int64(299),
#  'latest news': np.int64(1127),
#  'news result': np.int64(1432),
#  'result daili': np.int64(1734),
#  'remov send': np.int64(1711),
#  'send get': np.int64(1822),
#  'game send': np.int64(674),
#  'send di': np.int64(1818),
#  ...}

# %% [markdown]
# ## N-grams
